# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # RANK

# %%
matrices = np.load('/Users/aryanshrivastava/Desktop/LLMWargamingConfidence/logging/across/3.5trank/run1/kendall_matrices.npz')

# %%
matrices['move1'].flatten().mean()
# Out:
# 0.2668421052631579

# %%
matrices['move2'].flatten().mean()
# Out:
# 0.16134502923976604

# %%
plt.figure(figsize=(10, 8))
sns.boxplot([matrices['move1'].flatten(), matrices['move2'].flatten()], linewidth=1.2)
plt.ylabel('Kendall Inconsistency')
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(matrices['move2'].flatten(), linewidth=1.2)
plt.ylabel('Kendall Inconsistency')
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
means = [[], []]
for i in range(1, 7):
    matrices = np.load(f'/Users/aryanshrivastava/Desktop/LLMWargamingConfidence/logging/across/4rank/run{i}/kendall_matrices.npz')
    mm1, mm2 = matrices['move1'].mean(), matrices['move2'].mean()
    means[0].append(mm1)
    means[1].append(mm2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[73], line 3
#       1 means = [[], []]
#       2 for i in range(1, 7):
# ----> 3     matrices = np.load(f'/Users/aryanshrivastava/Desktop/LLMWargamingConfidence/logging/across/4rank/run{i}/kendall_matrices.npz')
#       4     mm1, mm2 = matrices['move1'].mean(), matrices['move2'].mean()
#       5     means[0].append(mm1)
#
# File ~/.venv/LLMWargamingConfidence/lib/python3.12/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# ...

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(means, linewidth=1.2)
plt.ylabel('Kendall Inconsistency')
plt.title('')
# Out:
# Text(0.5, 1.0, '')
